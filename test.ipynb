# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage

# %%
src=cv2.imread("earth.png",0)
kernel=np.array([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])

# %%
dst_corr=cv2.filter2D(src,-1,kernel)
plt.imshow(dst_corr)
